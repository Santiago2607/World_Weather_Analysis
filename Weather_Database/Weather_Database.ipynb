# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 769

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        
            
        # Append the city information into the city_data list
        city_data.append({"City":city.title(),
                        "Lat":city_lat,
                        "Lng":city_lng,
                        "Max Temp":city_max_temp,
                        "Humidity":city_humidity,
                        "Cloudiness":city_clouds,
                        "Wind Speed":city_wind,
                        "Country":city_country,
                        "Current Weather":city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | punta arenas
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | nichlaul
# Processing Record 4 of Set 1 | ust-tsilma
# Processing Record 5 of Set 1 | severo-kurilsk
# Processing Record 6 of Set 1 | taua
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | saint-raymond
# Processing Record 9 of Set 1 | ilulissat
# Processing Record 10 of Set 1 | agirish
# Processing Record 11 of Set 1 | ada
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | sabha
# Processing Record 15 of Set 1 | palmer
# Processing Record 16 of Set 1 | thoen
# Processing Record 17 of Set 1 | norman wells
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | alofi
# Processing Record 20 of Set 1 | campo largo
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | union
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | manokwari
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | haines junction
# Processing Record 29 of Set 1 | krasnyy yar
# Processing Record 30 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 1 | new norfolk
# Processing Record 32 of Set 1 | port elizabeth
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | yellowknife
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | todos santos
# Processing Record 37 of Set 1 | alexandria
# Processing Record 38 of Set 1 | boysun
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | atuona
# Processing Record 41 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 1 | caravelas
# Processing Record 43 of Set 1 | kitimat
# Processing Record 44 of Set 1 | ushuaia
# Processing Record 45 of Set 1 | pokrovsk
# Processing Record 46 of Set 1 | kiverion
# City not found. Skipping...
# Processing Record 47 of Set 1 | churapcha
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | busselton
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | pemangkat
# Processing Record 2 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 2 | samarai
# Processing Record 4 of Set 2 | batangafo
# Processing Record 5 of Set 2 | bambous virieux
# Processing Record 6 of Set 2 | kavieng
# Processing Record 7 of Set 2 | port alfred
# Processing Record 8 of Set 2 | laiagam
# City not found. Skipping...
# Processing Record 9 of Set 2 | arraial do cabo
# Processing Record 10 of Set 2 | provideniya
# Processing Record 11 of Set 2 | bengkulu
# Processing Record 12 of Set 2 | ancud
# Processing Record 13 of Set 2 | oksbol
# Processing Record 14 of Set 2 | ati
# Processing Record 15 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | cape town
# Processing Record 17 of Set 2 | port lincoln
# Processing Record 18 of Set 2 | sorong
# Processing Record 19 of Set 2 | phuket
# Processing Record 20 of Set 2 | vostok
# Processing Record 21 of Set 2 | masvingo
# Processing Record 22 of Set 2 | hobart
# Processing Record 23 of Set 2 | leningradskiy
# Processing Record 24 of Set 2 | karauzyak
# City not found. Skipping...
# Processing Record 25 of Set 2 | stornoway
# Processing Record 26 of Set 2 | tezu
# Processing Record 27 of Set 2 | padang
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | vao
# Processing Record 30 of Set 2 | mataura
# Processing Record 31 of Set 2 | mecca
# Processing Record 32 of Set 2 | port-gentil
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 2 | college
# Processing Record 36 of Set 2 | sao paulo de olivenca
# Processing Record 37 of Set 2 | hilo
# Processing Record 38 of Set 2 | adrar
# Processing Record 39 of Set 2 | mehamn
# Processing Record 40 of Set 2 | dikson
# Processing Record 41 of Set 2 | narsaq
# Processing Record 42 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 2 | kathu
# Processing Record 44 of Set 2 | pevek
# Processing Record 45 of Set 2 | we
# City not found. Skipping...
# Processing Record 46 of Set 2 | fereydun kenar
# Processing Record 47 of Set 2 | ribeira grande
# Processing Record 48 of Set 2 | hualmay
# Processing Record 49 of Set 2 | laguna
# Processing Record 50 of Set 2 | alekseyevsk
# Processing Record 1 of Set 3 | ponferrada
# Processing Record 2 of Set 3 | kahului
# Processing Record 3 of Set 3 | mwinilunga
# Processing Record 4 of Set 3 | naze
# Processing Record 5 of Set 3 | clyde river
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | nanortalik
# Processing Record 8 of Set 3 | san jose
# Processing Record 9 of Set 3 | salalah
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | panjab
# Processing Record 12 of Set 3 | turukhansk
# Processing Record 13 of Set 3 | marienburg
# Processing Record 14 of Set 3 | ordynskoye
# Processing Record 15 of Set 3 | faya
# Processing Record 16 of Set 3 | storforshei
# Processing Record 17 of Set 3 | lagoa
# Processing Record 18 of Set 3 | baiyin
# Processing Record 19 of Set 3 | santa flavia
# Processing Record 20 of Set 3 | sabla
# Processing Record 21 of Set 3 | selfoss
# Processing Record 22 of Set 3 | fillan
# Processing Record 23 of Set 3 | upernavik
# Processing Record 24 of Set 3 | geraldton
# Processing Record 25 of Set 3 | sitka
# Processing Record 26 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 27 of Set 3 | tucurui
# Processing Record 28 of Set 3 | flinders
# Processing Record 29 of Set 3 | muros
# Processing Record 30 of Set 3 | inhambane
# Processing Record 31 of Set 3 | hithadhoo
# Processing Record 32 of Set 3 | trinidad
# Processing Record 33 of Set 3 | kaputa
# Processing Record 34 of Set 3 | fort nelson
# Processing Record 35 of Set 3 | esperance
# Processing Record 36 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 3 | coihaique
# Processing Record 38 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 3 | maku
# Processing Record 40 of Set 3 | praia da vitoria
# Processing Record 41 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 3 | kodiak
# Processing Record 43 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 3 | ekhabi
# Processing Record 45 of Set 3 | port-cartier
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | saskylakh
# Processing Record 48 of Set 3 | mao
# Processing Record 49 of Set 3 | viransehir
# Processing Record 50 of Set 3 | panzhihua
# Processing Record 1 of Set 4 | thisted
# Processing Record 2 of Set 4 | maracaibo
# Processing Record 3 of Set 4 | stolac
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | kaili
# Processing Record 6 of Set 4 | acaponeta
# Processing Record 7 of Set 4 | nanchong
# Processing Record 8 of Set 4 | mahebourg
# Processing Record 9 of Set 4 | balimo
# City not found. Skipping...
# Processing Record 10 of Set 4 | shenjiamen
# Processing Record 11 of Set 4 | sinjar
# Processing Record 12 of Set 4 | klaksvik
# Processing Record 13 of Set 4 | bilibino
# Processing Record 14 of Set 4 | bandarbeyla
# Processing Record 15 of Set 4 | valparaiso
# Processing Record 16 of Set 4 | el real de santa maria
# Processing Record 17 of Set 4 | viedma
# Processing Record 18 of Set 4 | simpang
# Processing Record 19 of Set 4 | riyadh
# Processing Record 20 of Set 4 | yar-sale
# Processing Record 21 of Set 4 | vestmanna
# Processing Record 22 of Set 4 | gat
# Processing Record 23 of Set 4 | haghartsin
# Processing Record 24 of Set 4 | ukiah
# Processing Record 25 of Set 4 | maghama
# City not found. Skipping...
# Processing Record 26 of Set 4 | la uribe
# City not found. Skipping...
# Processing Record 27 of Set 4 | cidreira
# Processing Record 28 of Set 4 | kapuskasing
# Processing Record 29 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 4 | tiarei
# Processing Record 31 of Set 4 | tocopilla
# Processing Record 32 of Set 4 | a
# City not found. Skipping...
# Processing Record 33 of Set 4 | sept-iles
# Processing Record 34 of Set 4 | thompson
# Processing Record 35 of Set 4 | vila franca do campo
# Processing Record 36 of Set 4 | ambilobe
# Processing Record 37 of Set 4 | colares
# Processing Record 38 of Set 4 | westport
# Processing Record 39 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 4 | bouar
# Processing Record 41 of Set 4 | puerto carreno
# Processing Record 42 of Set 4 | badaojiang
# City not found. Skipping...
# Processing Record 43 of Set 4 | havre-saint-pierre
# Processing Record 44 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 45 of Set 4 | valenca do piaui
# Processing Record 46 of Set 4 | parras
# City not found. Skipping...
# Processing Record 47 of Set 4 | mar del plata
# Processing Record 48 of Set 4 | honiara
# Processing Record 49 of Set 4 | tiksi
# Processing Record 50 of Set 4 | san cristobal
# Processing Record 1 of Set 5 | richards bay
# Processing Record 2 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 5 | miquelon
# Processing Record 4 of Set 5 | berlevag
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | roald
# Processing Record 7 of Set 5 | penzance
# Processing Record 8 of Set 5 | zyryanka
# Processing Record 9 of Set 5 | nouadhibou
# Processing Record 10 of Set 5 | lavrentiya
# Processing Record 11 of Set 5 | channel-port aux basques
# Processing Record 12 of Set 5 | huarmey
# Processing Record 13 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 5 | lincoln
# Processing Record 15 of Set 5 | mpulungu
# Processing Record 16 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 17 of Set 5 | quatre cocos
# Processing Record 18 of Set 5 | ismailia
# Processing Record 19 of Set 5 | komsomolskiy
# Processing Record 20 of Set 5 | auki
# Processing Record 21 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 5 | amahai
# Processing Record 23 of Set 5 | zhelnino
# City not found. Skipping...
# Processing Record 24 of Set 5 | noormarkku
# Processing Record 25 of Set 5 | tinskoy
# Processing Record 26 of Set 5 | coffs harbour
# Processing Record 27 of Set 5 | nikolskoye
# Processing Record 28 of Set 5 | isla mujeres
# Processing Record 29 of Set 5 | bethel
# Processing Record 30 of Set 5 | saint-philippe
# Processing Record 31 of Set 5 | salinas
# Processing Record 32 of Set 5 | dingle
# Processing Record 33 of Set 5 | mezen
# Processing Record 34 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 35 of Set 5 | katsuura
# Processing Record 36 of Set 5 | luanda
# Processing Record 37 of Set 5 | wattegama
# Processing Record 38 of Set 5 | torbay
# Processing Record 39 of Set 5 | aswan
# Processing Record 40 of Set 5 | kalmunai
# Processing Record 41 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 42 of Set 5 | marzuq
# Processing Record 43 of Set 5 | dhanaura
# Processing Record 44 of Set 5 | vardo
# Processing Record 45 of Set 5 | kurilsk
# Processing Record 46 of Set 5 | pacific grove
# Processing Record 47 of Set 5 | yamada
# Processing Record 48 of Set 5 | hobyo
# Processing Record 49 of Set 5 | te anau
# Processing Record 50 of Set 5 | bathsheba
# Processing Record 1 of Set 6 | qeshm
# Processing Record 2 of Set 6 | fairbanks
# Processing Record 3 of Set 6 | solwezi
# Processing Record 4 of Set 6 | kruisfontein
# Processing Record 5 of Set 6 | blyznyuky
# Processing Record 6 of Set 6 | khatanga
# Processing Record 7 of Set 6 | noyabrsk
# Processing Record 8 of Set 6 | dudinka
# Processing Record 9 of Set 6 | gillette
# Processing Record 10 of Set 6 | marigot
# Processing Record 11 of Set 6 | ciudad guayana
# Processing Record 12 of Set 6 | rocha
# Processing Record 13 of Set 6 | hervey bay
# Processing Record 14 of Set 6 | kingman
# Processing Record 15 of Set 6 | east london
# Processing Record 16 of Set 6 | touros
# Processing Record 17 of Set 6 | mahajanga
# Processing Record 18 of Set 6 | ipixuna
# Processing Record 19 of Set 6 | pilar
# Processing Record 20 of Set 6 | georgetown
# Processing Record 21 of Set 6 | paita
# Processing Record 22 of Set 6 | tuktoyaktuk
# Processing Record 23 of Set 6 | port hueneme
# Processing Record 24 of Set 6 | acapulco
# Processing Record 25 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 6 | chumikan
# Processing Record 27 of Set 6 | arzgir
# Processing Record 28 of Set 6 | roma
# Processing Record 29 of Set 6 | kapit
# Processing Record 30 of Set 6 | kanashevo
# Processing Record 31 of Set 6 | nemuro
# Processing Record 32 of Set 6 | longyearbyen
# Processing Record 33 of Set 6 | sayyan
# Processing Record 34 of Set 6 | prince rupert
# Processing Record 35 of Set 6 | guerrero negro
# Processing Record 36 of Set 6 | henties bay
# Processing Record 37 of Set 6 | lodja
# Processing Record 38 of Set 6 | rio grande
# Processing Record 39 of Set 6 | mount gambier
# Processing Record 40 of Set 6 | chokurdakh
# Processing Record 41 of Set 6 | smirnykh
# Processing Record 42 of Set 6 | moengo
# Processing Record 43 of Set 6 | russell
# Processing Record 44 of Set 6 | port hedland
# Processing Record 45 of Set 6 | poum
# Processing Record 46 of Set 6 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 6 | tuatapere
# Processing Record 48 of Set 6 | shache
# Processing Record 49 of Set 6 | kaitangata
# Processing Record 50 of Set 6 | faanui
# Processing Record 1 of Set 7 | dicabisagan
# Processing Record 2 of Set 7 | tecoanapa
# Processing Record 3 of Set 7 | belmonte
# Processing Record 4 of Set 7 | aripuana
# Processing Record 5 of Set 7 | srednekolymsk
# Processing Record 6 of Set 7 | saint george
# Processing Record 7 of Set 7 | burica
# City not found. Skipping...
# Processing Record 8 of Set 7 | madingou
# Processing Record 9 of Set 7 | port hardy
# Processing Record 10 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 7 | otane
# Processing Record 12 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 13 of Set 7 | brae
# Processing Record 14 of Set 7 | chapais
# Processing Record 15 of Set 7 | constitucion
# Processing Record 16 of Set 7 | ahja
# Processing Record 17 of Set 7 | cabo san lucas
# Processing Record 18 of Set 7 | hasaki
# Processing Record 19 of Set 7 | batagay
# Processing Record 20 of Set 7 | verkhnevilyuysk
# Processing Record 21 of Set 7 | payo
# Processing Record 22 of Set 7 | mocambique
# City not found. Skipping...
# Processing Record 23 of Set 7 | bidar
# Processing Record 24 of Set 7 | chuy
# Processing Record 25 of Set 7 | bintulu
# Processing Record 26 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 7 | the pas
# Processing Record 28 of Set 7 | ibipeba
# Processing Record 29 of Set 7 | bubaque
# Processing Record 30 of Set 7 | vajszlo
# Processing Record 31 of Set 7 | vila velha
# Processing Record 32 of Set 7 | balykshi
# Processing Record 33 of Set 7 | mut
# Processing Record 34 of Set 7 | presidencia roque saenz pena
# Processing Record 35 of Set 7 | nagato
# Processing Record 36 of Set 7 | liling
# Processing Record 37 of Set 7 | dalvik
# Processing Record 38 of Set 7 | maceio
# Processing Record 39 of Set 7 | dunedin
# Processing Record 40 of Set 7 | yumen
# Processing Record 41 of Set 7 | trofors
# Processing Record 42 of Set 7 | sao pedro do sul
# Processing Record 43 of Set 7 | kashan
# Processing Record 44 of Set 7 | beringovskiy
# Processing Record 45 of Set 7 | zhezkazgan
# Processing Record 46 of Set 7 | luderitz
# Processing Record 47 of Set 7 | praia
# Processing Record 48 of Set 7 | saint anthony
# Processing Record 49 of Set 7 | coracao de maria
# Processing Record 50 of Set 7 | blagoyevo
# Processing Record 1 of Set 8 | kieta
# Processing Record 2 of Set 8 | saldanha
# Processing Record 3 of Set 8 | akcakoca
# Processing Record 4 of Set 8 | korla
# Processing Record 5 of Set 8 | mayo
# Processing Record 6 of Set 8 | nova olinda do norte
# Processing Record 7 of Set 8 | meulaboh
# Processing Record 8 of Set 8 | poso
# Processing Record 9 of Set 8 | guangzhou
# Processing Record 10 of Set 8 | mola di bari
# Processing Record 11 of Set 8 | lafiagi
# Processing Record 12 of Set 8 | gdov
# Processing Record 13 of Set 8 | mackenzie
# Processing Record 14 of Set 8 | arman
# Processing Record 15 of Set 8 | paamiut
# Processing Record 16 of Set 8 | vermilion
# Processing Record 17 of Set 8 | casa nova
# Processing Record 18 of Set 8 | husavik
# Processing Record 19 of Set 8 | moratuwa
# Processing Record 20 of Set 8 | horsham
# Processing Record 21 of Set 8 | wuwei
# Processing Record 22 of Set 8 | vanavara
# Processing Record 23 of Set 8 | omboue
# Processing Record 24 of Set 8 | victoria
# Processing Record 25 of Set 8 | singleton
# Processing Record 26 of Set 8 | grindavik
# Processing Record 27 of Set 8 | kenai
# Processing Record 28 of Set 8 | huanren
# Processing Record 29 of Set 8 | mountain home
# Processing Record 30 of Set 8 | columbus
# Processing Record 31 of Set 8 | kaeo
# Processing Record 32 of Set 8 | andilamena
# Processing Record 33 of Set 8 | mangrol
# Processing Record 34 of Set 8 | nkowakowa
# Processing Record 35 of Set 8 | tabou
# Processing Record 36 of Set 8 | opuwo
# Processing Record 37 of Set 8 | denpasar
# Processing Record 38 of Set 8 | karema
# Processing Record 39 of Set 8 | saint-augustin
# Processing Record 40 of Set 8 | jiayuguan
# Processing Record 41 of Set 8 | mabaruma
# Processing Record 42 of Set 8 | marawi
# Processing Record 43 of Set 8 | sinnamary
# Processing Record 44 of Set 8 | liwale
# Processing Record 45 of Set 8 | destin
# Processing Record 46 of Set 8 | chifeng
# Processing Record 47 of Set 8 | hanmer springs
# Processing Record 48 of Set 8 | strai
# Processing Record 49 of Set 8 | mena
# Processing Record 50 of Set 8 | merke
# Processing Record 1 of Set 9 | siemiatycze
# Processing Record 2 of Set 9 | rafaela
# Processing Record 3 of Set 9 | quelimane
# Processing Record 4 of Set 9 | avila
# Processing Record 5 of Set 9 | zhenlai
# Processing Record 6 of Set 9 | maumere
# Processing Record 7 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 8 of Set 9 | sioux lookout
# Processing Record 9 of Set 9 | iqaluit
# Processing Record 10 of Set 9 | beira
# Processing Record 11 of Set 9 | byron bay
# Processing Record 12 of Set 9 | muravlenko
# Processing Record 13 of Set 9 | ormara
# Processing Record 14 of Set 9 | kolyvan
# Processing Record 15 of Set 9 | okhotsk
# Processing Record 16 of Set 9 | loiza
# Processing Record 17 of Set 9 | gusau
# Processing Record 18 of Set 9 | tadine
# Processing Record 19 of Set 9 | puquio
# Processing Record 20 of Set 9 | gubkinskiy
# Processing Record 21 of Set 9 | dong hoi
# Processing Record 22 of Set 9 | capreol
# Processing Record 23 of Set 9 | holbeach
# Processing Record 24 of Set 9 | garowe
# Processing Record 25 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 9 | tautira
# Processing Record 27 of Set 9 | veraval
# Processing Record 28 of Set 9 | shimoda
# Processing Record 29 of Set 9 | luan
# Processing Record 30 of Set 9 | hamilton
# Processing Record 31 of Set 9 | los llanos de aridane
# Processing Record 32 of Set 9 | asau
# Processing Record 33 of Set 9 | pocatello
# Processing Record 34 of Set 9 | mount isa
# Processing Record 35 of Set 9 | houma
# Processing Record 36 of Set 9 | cayenne
# Processing Record 37 of Set 9 | ixtapa
# Processing Record 38 of Set 9 | pangai
# Processing Record 39 of Set 9 | mbabane
# Processing Record 40 of Set 9 | bali
# Processing Record 41 of Set 9 | karamay
# City not found. Skipping...
# Processing Record 42 of Set 9 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 9 | souillac
# Processing Record 44 of Set 9 | kaura namoda
# Processing Record 45 of Set 9 | imbituba
# Processing Record 46 of Set 9 | gunjur
# Processing Record 47 of Set 9 | sarkand
# Processing Record 48 of Set 9 | chicama
# Processing Record 49 of Set 9 | talnakh
# Processing Record 50 of Set 9 | vila
# Processing Record 1 of Set 10 | san patricio
# Processing Record 2 of Set 10 | sasina
# Processing Record 3 of Set 10 | banjar
# Processing Record 4 of Set 10 | bria
# Processing Record 5 of Set 10 | lee
# Processing Record 6 of Set 10 | coos bay
# Processing Record 7 of Set 10 | batticaloa
# Processing Record 8 of Set 10 | karumbakkam
# Processing Record 9 of Set 10 | kimbe
# Processing Record 10 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 10 | tsarychanka
# Processing Record 12 of Set 10 | atambua
# Processing Record 13 of Set 10 | langres
# Processing Record 14 of Set 10 | adre
# Processing Record 15 of Set 10 | tecolutla
# Processing Record 16 of Set 10 | pozo colorado
# Processing Record 17 of Set 10 | khani
# Processing Record 18 of Set 10 | bitung
# Processing Record 19 of Set 10 | natal
# Processing Record 20 of Set 10 | tera
# Processing Record 21 of Set 10 | miranda
# Processing Record 22 of Set 10 | gizo
# Processing Record 23 of Set 10 | stokmarknes
# Processing Record 24 of Set 10 | nanyang
# Processing Record 25 of Set 10 | kollumerland
# City not found. Skipping...
# Processing Record 26 of Set 10 | sao miguel do araguaia
# Processing Record 27 of Set 10 | mwaro
# Processing Record 28 of Set 10 | sinegorye
# Processing Record 29 of Set 10 | san blas
# Processing Record 30 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 31 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 32 of Set 10 | karla
# Processing Record 33 of Set 10 | hare bay
# Processing Record 34 of Set 10 | ilo
# Processing Record 35 of Set 10 | sopot
# Processing Record 36 of Set 10 | vryburg
# Processing Record 37 of Set 10 | tazovskiy
# Processing Record 38 of Set 10 | lillooet
# Processing Record 39 of Set 10 | inongo
# Processing Record 40 of Set 10 | conde
# Processing Record 41 of Set 10 | babushkin
# Processing Record 42 of Set 10 | labuhan
# Processing Record 43 of Set 10 | mwene-ditu
# Processing Record 44 of Set 10 | ahipara
# Processing Record 45 of Set 10 | okahandja
# Processing Record 46 of Set 10 | iberia
# Processing Record 47 of Set 10 | namibe
# Processing Record 48 of Set 10 | dawei
# Processing Record 49 of Set 10 | kirakira
# Processing Record 50 of Set 10 | comodoro rivadavia
# Processing Record 1 of Set 11 | bukene
# Processing Record 2 of Set 11 | livanatai
# Processing Record 3 of Set 11 | avera
# Processing Record 4 of Set 11 | karratha
# Processing Record 5 of Set 11 | tokmak
# Processing Record 6 of Set 11 | lompoc
# Processing Record 7 of Set 11 | pangnirtung
# Processing Record 8 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 11 | nome
# Processing Record 10 of Set 11 | ituni
# City not found. Skipping...
# Processing Record 11 of Set 11 | mahibadhoo
# Processing Record 12 of Set 11 | verkhnyaya inta
# Processing Record 13 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 14 of Set 11 | portree
# Processing Record 15 of Set 11 | port moresby
# Processing Record 16 of Set 11 | airai
# Processing Record 17 of Set 11 | cherskiy
# Processing Record 18 of Set 11 | sangar
# Processing Record 19 of Set 11 | artyk
# City not found. Skipping...
# Processing Record 20 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 21 of Set 11 | tire
# Processing Record 22 of Set 11 | sao lourenco do sul
# Processing Record 23 of Set 11 | sobolevo
# Processing Record 24 of Set 11 | oranjemund
# Processing Record 25 of Set 11 | hun
# Processing Record 26 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 11 | charqueada
# Processing Record 28 of Set 11 | winslow
# Processing Record 29 of Set 11 | esil
# Processing Record 30 of Set 11 | lafia
# Processing Record 31 of Set 11 | sibiti
# Processing Record 32 of Set 11 | yerbogachen
# Processing Record 33 of Set 11 | karasjok
# Processing Record 34 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 35 of Set 11 | porto tolle
# Processing Record 36 of Set 11 | saint-pierre
# Processing Record 37 of Set 11 | north bend
# Processing Record 38 of Set 11 | amapa
# Processing Record 39 of Set 11 | campos altos
# Processing Record 40 of Set 11 | muncar
# Processing Record 41 of Set 11 | biltine
# Processing Record 42 of Set 11 | kralendijk
# Processing Record 43 of Set 11 | jurado
# Processing Record 44 of Set 11 | biak
# Processing Record 45 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 11 | sao joao da barra
# Processing Record 47 of Set 11 | dzheyrakh
# Processing Record 48 of Set 11 | hailar
# Processing Record 49 of Set 11 | otradnoye
# Processing Record 50 of Set 11 | port blair
# Processing Record 1 of Set 12 | kattivakkam
# Processing Record 2 of Set 12 | puerto madero
# Processing Record 3 of Set 12 | kijang
# Processing Record 4 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 5 of Set 12 | lexington
# Processing Record 6 of Set 12 | havelock
# Processing Record 7 of Set 12 | san vicente
# Processing Record 8 of Set 12 | ishurdi
# Processing Record 9 of Set 12 | balabac
# Processing Record 10 of Set 12 | whitehorse
# Processing Record 11 of Set 12 | makakilo city
# Processing Record 12 of Set 12 | ostrovnoy
# Processing Record 13 of Set 12 | kumluca
# Processing Record 14 of Set 12 | moranbah
# Processing Record 15 of Set 12 | ozark
# Processing Record 16 of Set 12 | soyo
# Processing Record 17 of Set 12 | westpunt
# City not found. Skipping...
# Processing Record 18 of Set 12 | broken hill
# Processing Record 19 of Set 12 | vestmannaeyjar
# Processing Record 20 of Set 12 | felanitx
# Processing Record 21 of Set 12 | cangucu
# Processing Record 22 of Set 12 | masallatah
# Processing Record 23 of Set 12 | maniitsoq
# Processing Record 24 of Set 12 | alyangula
# Processing Record 25 of Set 12 | pineville
# Processing Record 26 of Set 12 | shihezi
# Processing Record 27 of Set 12 | newton
# Processing Record 28 of Set 12 | povenets
# Processing Record 29 of Set 12 | codrington
# Processing Record 30 of Set 12 | deputatskiy
# Processing Record 31 of Set 12 | roebourne
# Processing Record 32 of Set 12 | vitry-le-francois
# Processing Record 33 of Set 12 | kanniyakumari
# Processing Record 34 of Set 12 | mapiripan
# Processing Record 35 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 36 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 37 of Set 12 | abancay
# Processing Record 38 of Set 12 | barra do garcas
# Processing Record 39 of Set 12 | xichang
# Processing Record 40 of Set 12 | yinchuan
# Processing Record 41 of Set 12 | baruun-urt
# Processing Record 42 of Set 12 | atar
# Processing Record 43 of Set 12 | bafoulabe
# Processing Record 44 of Set 12 | tazmalt
# Processing Record 45 of Set 12 | misratah
# Processing Record 46 of Set 12 | khandyga
# Processing Record 47 of Set 12 | oranjestad
# Processing Record 48 of Set 12 | nizhniy kuranakh
# Processing Record 49 of Set 12 | aginskoye
# Processing Record 50 of Set 12 | honningsvag
# Processing Record 1 of Set 13 | slough
# Processing Record 2 of Set 13 | pisco
# Processing Record 3 of Set 13 | port macquarie
# Processing Record 4 of Set 13 | serenje
# Processing Record 5 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 6 of Set 13 | along
# Processing Record 7 of Set 13 | la ronge
# Processing Record 8 of Set 13 | turayf
# Processing Record 9 of Set 13 | methoni
# Processing Record 10 of Set 13 | chute-aux-outardes
# Processing Record 11 of Set 13 | calama
# Processing Record 12 of Set 13 | yarmouth
# Processing Record 13 of Set 13 | dorogino
# Processing Record 14 of Set 13 | parana
# Processing Record 15 of Set 13 | omsukchan
# Processing Record 16 of Set 13 | evensk
# Processing Record 17 of Set 13 | oyama
# Processing Record 18 of Set 13 | nabire
# Processing Record 19 of Set 13 | vagur
# Processing Record 20 of Set 13 | kysyl-syr
# Processing Record 21 of Set 13 | lasa
# Processing Record 22 of Set 13 | acarau
# Processing Record 23 of Set 13 | labuan
# Processing Record 24 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 25 of Set 13 | kovdor
# Processing Record 26 of Set 13 | bulgan
# Processing Record 27 of Set 13 | sanmenxia
# Processing Record 28 of Set 13 | tostedt
# Processing Record 29 of Set 13 | tamale
# Processing Record 30 of Set 13 | tessalit
# Processing Record 31 of Set 13 | sibolga
# Processing Record 32 of Set 13 | amarante do maranhao
# Processing Record 33 of Set 13 | road town
# Processing Record 34 of Set 13 | lata
# Processing Record 35 of Set 13 | gariaband
# Processing Record 36 of Set 13 | znamenskoye
# Processing Record 37 of Set 13 | tsnori
# Processing Record 38 of Set 13 | zhucheng
# Processing Record 39 of Set 13 | marsaxlokk
# Processing Record 40 of Set 13 | kyabe
# Processing Record 41 of Set 13 | vaxjo
# Processing Record 42 of Set 13 | mantua
# Processing Record 43 of Set 13 | shamary
# Processing Record 44 of Set 13 | xiongzhou
# Processing Record 45 of Set 13 | chico
# Processing Record 46 of Set 13 | altay
# Processing Record 47 of Set 13 | izhma
# Processing Record 48 of Set 13 | lorengau
# Processing Record 49 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 50 of Set 13 | severo-yeniseyskiy
# Processing Record 1 of Set 14 | pokosnoye
# Processing Record 2 of Set 14 | yantal
# Processing Record 3 of Set 14 | egvekinot
# Processing Record 4 of Set 14 | sorland
# Processing Record 5 of Set 14 | port pirie
# Processing Record 6 of Set 14 | imisli
# City not found. Skipping...
# Processing Record 7 of Set 14 | pingshan
# Processing Record 8 of Set 14 | etropole
# Processing Record 9 of Set 14 | stejaru
# Processing Record 10 of Set 14 | tonstad
# Processing Record 11 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 12 of Set 14 | cravo norte
# Processing Record 13 of Set 14 | mergui
# City not found. Skipping...
# Processing Record 14 of Set 14 | mahon
# Processing Record 15 of Set 14 | gushikawa
# Processing Record 16 of Set 14 | carlow
# Processing Record 17 of Set 14 | kuruman
# Processing Record 18 of Set 14 | arkadelphia
# Processing Record 19 of Set 14 | wakkanai
# Processing Record 20 of Set 14 | aktau
# Processing Record 21 of Set 14 | jalu
# Processing Record 22 of Set 14 | kaa-khem
# Processing Record 23 of Set 14 | virginia beach
# Processing Record 24 of Set 14 | sao domingos do maranhao
# Processing Record 25 of Set 14 | cururupu
# Processing Record 26 of Set 14 | mnogovershinnyy
# Processing Record 27 of Set 14 | xining
# Processing Record 28 of Set 14 | ariogala
# Processing Record 29 of Set 14 | hallingby
# City not found. Skipping...
# Processing Record 30 of Set 14 | benghazi
# Processing Record 31 of Set 14 | bilma
# Processing Record 32 of Set 14 | marystown
# Processing Record 33 of Set 14 | miraflores
# Processing Record 34 of Set 14 | necochea
# Processing Record 35 of Set 14 | kurumkan
# Processing Record 36 of Set 14 | holbaek
# Processing Record 37 of Set 14 | mudyuga
# City not found. Skipping...
# Processing Record 38 of Set 14 | independence
# Processing Record 39 of Set 14 | aykhal
# Processing Record 40 of Set 14 | sechura
# Processing Record 41 of Set 14 | north mankato
# Processing Record 42 of Set 14 | sur
# Processing Record 43 of Set 14 | liaocheng
# Processing Record 44 of Set 14 | ulladulla
# Processing Record 45 of Set 14 | emerald
# Processing Record 46 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 14 | charleston
# Processing Record 48 of Set 14 | canals
# Processing Record 49 of Set 14 | alta floresta
# Processing Record 50 of Set 14 | kjollefjord
# Processing Record 1 of Set 15 | antsohihy
# Processing Record 2 of Set 15 | matucana
# Processing Record 3 of Set 15 | chase
# Processing Record 4 of Set 15 | tikhvin
# Processing Record 5 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 6 of Set 15 | lucapa
# Processing Record 7 of Set 15 | half moon bay
# Processing Record 8 of Set 15 | chardara
# Processing Record 9 of Set 15 | mugur-aksy
# Processing Record 10 of Set 15 | newport
# Processing Record 11 of Set 15 | sao domingos
# Processing Record 12 of Set 15 | cambridge
# Processing Record 13 of Set 15 | cap malheureux
# Processing Record 14 of Set 15 | mwanza
# Processing Record 15 of Set 15 | birao
# Processing Record 16 of Set 15 | halifax
# Processing Record 17 of Set 15 | mareeba
# Processing Record 18 of Set 15 | takoradi
# Processing Record 19 of Set 15 | rakovnik
# Processing Record 20 of Set 15 | urucara
# Processing Record 21 of Set 15 | severodvinsk
# Processing Record 22 of Set 15 | bardiyah
# Processing Record 23 of Set 15 | baykit
# Processing Record 24 of Set 15 | znamensk
# Processing Record 25 of Set 15 | sampit
# Processing Record 26 of Set 15 | etchoropo
# Processing Record 27 of Set 15 | araouane
# Processing Record 28 of Set 15 | kouqian
# Processing Record 29 of Set 15 | uvira
# Processing Record 30 of Set 15 | bukama
# Processing Record 31 of Set 15 | kamaishi
# Processing Record 32 of Set 15 | dongsheng
# Processing Record 33 of Set 15 | rybinsk
# Processing Record 34 of Set 15 | olafsvik
# Processing Record 35 of Set 15 | marabba
# Processing Record 36 of Set 15 | tromso
# Processing Record 37 of Set 15 | chernyshevskiy
# Processing Record 38 of Set 15 | taltal
# Processing Record 39 of Set 15 | cowra
# Processing Record 40 of Set 15 | hami
# Processing Record 41 of Set 15 | maragogi
# Processing Record 42 of Set 15 | santiago de cao
# Processing Record 43 of Set 15 | gazanjyk
# Processing Record 44 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 15 | scituate
# Processing Record 46 of Set 15 | gerash
# Processing Record 47 of Set 15 | ust-nera
# Processing Record 48 of Set 15 | bairiki
# Processing Record 49 of Set 15 | fukue
# Processing Record 50 of Set 15 | revda
# Processing Record 1 of Set 16 | matara
# Processing Record 2 of Set 16 | ecija
# Processing Record 3 of Set 16 | merauke
# Processing Record 4 of Set 16 | tuapse
# Processing Record 5 of Set 16 | marathon
# Processing Record 6 of Set 16 | pascagoula
# Processing Record 7 of Set 16 | daru
# Processing Record 8 of Set 16 | aketi
# Processing Record 9 of Set 16 | bayir
# Processing Record 10 of Set 16 | eregli
# Processing Record 11 of Set 16 | xinzhi
# Processing Record 12 of Set 16 | macaboboni
# City not found. Skipping...
# Processing Record 13 of Set 16 | kununurra
# Processing Record 14 of Set 16 | olkhovka
# Processing Record 15 of Set 16 | hay river
# Processing Record 16 of Set 16 | santa vitoria do palmar
# Processing Record 17 of Set 16 | troitsk
# Processing Record 18 of Set 16 | santa lucia
# Processing Record 19 of Set 16 | hofn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 697

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 0               Punta Arenas -53.1500  -70.9167     57.31        51
# 1                   Hermanus -34.4187   19.2345     64.80        85
# 2                   Nichlaul  27.3167   83.7333     61.68        65
# 3                 Ust-Tsilma  65.4410   52.1498     24.93        95
# 4             Severo-Kurilsk  50.6789  156.1250     33.73        64
# ..                       ...      ...       ...       ...       ...
# 692                Hay River  60.8156 -115.7999     19.38        86
# 693  Santa Vitoria Do Palmar -33.5189  -53.3681     68.70        81
# 694                  Troitsk  54.0979   61.5773     37.33        88
# 695              Santa Lucia  27.9117  -15.5407     66.76        88
# 696                     Hofn  64.2539  -15.2082     44.17        80
#
#      Cloudiness  Wind Speed Country  Current Weather
# 0            20        8.05      CL       few clouds
# 1             0       13.02      ZA       light rain
# 2             0        2.59      IN        clear sky
# 3           100        9.24      RU       light snow
# 4            97       13.42      RU  overcast clouds
# ..          ...         ...     ...              ...
# 692         100        8.05      CA  overcast clouds
# 693         100       12.03      BR  overcast clouds
# 694         100       18.68      RU  overcast clouds
# 695          20        5.75      ES       few clouds
# 696         100        9.37      IS  overcast clouds
#
# [697 rows x 9 columns]

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas -53.1500  -70.9167     57.31        51          20
# 1        Hermanus -34.4187   19.2345     64.80        85           0
# 2        Nichlaul  27.3167   83.7333     61.68        65           0
# 3      Ust-Tsilma  65.4410   52.1498     24.93        95         100
# 4  Severo-Kurilsk  50.6789  156.1250     33.73        64          97
# 5            Taua  -5.9667  -40.3000     91.65        29          42
# 6       Jamestown  42.0970  -79.2353     42.39        77         100
# 7   Saint-Raymond  45.4670  -73.6095     55.38        79          75
# 8       Ilulissat  69.2167  -51.1000     24.82        68          99
# 9         Agirish  61.9247   63.0231      6.62        96          97
#
#    Wind Speed Country   Current Weather
# 0        8.05      CL        few clouds
# 1       13.02      ZA        light rain
# 2        2.59      IN         clear sky
# 3        9.24      RU        light snow
# 4       13.42      RU   overcast clouds
# 5       10.09      BR  scattered clouds
# 6        8.99      US        light rain
# 7       17.27      CA     broken clouds
# 8        3.44      GL   overcast clouds
# 9        5.30      RU   overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Weather'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "city", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Weather"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Punta Arenas      CL -53.1500  -70.9167     57.31        51          20
# 1        Hermanus      ZA -34.4187   19.2345     64.80        85           0
# 2        Nichlaul      IN  27.3167   83.7333     61.68        65           0
# 3      Ust-Tsilma      RU  65.4410   52.1498     24.93        95         100
# 4  Severo-Kurilsk      RU  50.6789  156.1250     33.73        64          97
# 5            Taua      BR  -5.9667  -40.3000     91.65        29          42
# 6       Jamestown      US  42.0970  -79.2353     42.39        77         100
# 7   Saint-Raymond      CA  45.4670  -73.6095     55.38        79          75
# 8       Ilulissat      GL  69.2167  -51.1000     24.82        68          99
# 9         Agirish      RU  61.9247   63.0231      6.62        96          97
#
#    Wind Speed   Current Weather
# 0        8.05        few clouds
# 1       13.02        light rain
# 2        2.59         clear sky
# 3        9.24        light snow
# 4       13.42   overcast clouds
# 5       10.09  scattered clouds
# 6        8.99        light rain
# 7       17.27     broken clouds
# 8        3.44   overcast clouds
# 9        5.30   overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                object
# Country             object
# Lat                float64
# Lng                float64
# Max Temp           float64
# Humidity             int64
# Cloudiness           int64
# Wind Speed         float64
# Current Weather     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
